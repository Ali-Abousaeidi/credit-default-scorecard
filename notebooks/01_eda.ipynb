# %% [markdown]
# # Phase 1 EDA
#
# This notebook is a lightweight entry point for the raw-data inspection. The repeatable report artifacts are generated by `python -m src.eda`.

# %%
from pathlib import Path
import pandas as pd

from src.config import RAW_GMSC_FILE, TARGET_COLUMN

data = pd.read_csv(RAW_GMSC_FILE)
data.shape, data[TARGET_COLUMN].mean()

# %%
data.head()

# %%
data.isna().mean().sort_values(ascending=False)

# %%
data.describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99]).T
